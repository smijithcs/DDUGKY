# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("smijithcs.csv")
df
# Out:
#                 names  stat  python  total  percetage status
# 0   ABHIMANYU RAVI CR    15      24     39      86.67   fail
# 1            AJITH TA    15      25     40      88.89   fail
# 2            AKSHAY A    18      24     42      93.33   pass
# 3      ALEN TOM SHAJI    18      25     43      95.56   pass
# 4          ANAND ANIL    16      25     41      91.11   pass
# 5           ANSAL M T    19      25     44      97.78   pass
# 6        ARUN KUMAR N    15      24     39      86.67   fail
# 7           ASWIN C S    13      24     37      82.22   fail
# 8      DIAVOOD NASSAR    16      24     40      88.89   fail
# 9       HARIPRIYA.K.U    17      24     41      91.11   pass
# 10       INDRAJITH KK    13      25     38      84.44   fail
# 11          JISHNU VS    15      25     40      88.89   fail
# 12       JISHNURAJ MP    15      23     38      84.44   fail
# 13             JOPIKA    13      24     37      82.22   fail
# ...

# %%
twopowers_sr=df["names"]

# %%
df["pass_fail_status"]=df["total"]>40

# %%
df
# Out:
#                 names  stat  python  total  percetage status  pass_fail_status
# 0   ABHIMANYU RAVI CR    15      24     39      86.67   fail             False
# 1            AJITH TA    15      25     40      88.89   fail             False
# 2            AKSHAY A    18      24     42      93.33   pass              True
# 3      ALEN TOM SHAJI    18      25     43      95.56   pass              True
# 4          ANAND ANIL    16      25     41      91.11   pass              True
# 5           ANSAL M T    19      25     44      97.78   pass              True
# 6        ARUN KUMAR N    15      24     39      86.67   fail             False
# 7           ASWIN C S    13      24     37      82.22   fail             False
# 8      DIAVOOD NASSAR    16      24     40      88.89   fail             False
# 9       HARIPRIYA.K.U    17      24     41      91.11   pass              True
# 10       INDRAJITH KK    13      25     38      84.44   fail             False
# ...

# %%
bm=df["pass_fail_status"]
bm
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34     True
# Name: pass_fail_status, dtype: bool

# %%
twopowers_sr[bm]
# Out:
# 2             AKSHAY A
# 3       ALEN TOM SHAJI
# 4           ANAND ANIL
# 5            ANSAL M T
# 9        HARIPRIYA.K.U
# 14        KEERTHI RAVI
# 15           KIRAN K S
# 17      MANCY MAMACHAN
# 20    MUHAMMED SIRAJ K
# 24             RAHUL N
# 25          RAMSHAD TA
# 26     SANIKA SAJEEVAN
# 28         SHAMMAS N M
# 32            SWATHIAS
# 34     VISHNU MUKUNDAN
# Name: names, dtype: object

# %%
df[["names","total"]][df["pass_fail_status"]]
# Out:
#                names  total
# 2           AKSHAY A     42
# 3     ALEN TOM SHAJI     43
# 4         ANAND ANIL     41
# 5          ANSAL M T     44
# 9      HARIPRIYA.K.U     41
# 14      KEERTHI RAVI     41
# 15         KIRAN K S     44
# 17    MANCY MAMACHAN     41
# 20  MUHAMMED SIRAJ K     43
# 24           RAHUL N     41
# 25        RAMSHAD TA     44
# 26   SANIKA SAJEEVAN     42
# 28       SHAMMAS N M     41
# 32          SWATHIAS     41
# 34   VISHNU MUKUNDAN     41

# %%
df[["names","total","percetage"]]
# Out:
#                 names  total  percetage
# 0   ABHIMANYU RAVI CR     39      86.67
# 1            AJITH TA     40      88.89
# 2            AKSHAY A     42      93.33
# 3      ALEN TOM SHAJI     43      95.56
# 4          ANAND ANIL     41      91.11
# 5           ANSAL M T     44      97.78
# 6        ARUN KUMAR N     39      86.67
# 7           ASWIN C S     37      82.22
# 8      DIAVOOD NASSAR     40      88.89
# 9       HARIPRIYA.K.U     41      91.11
# 10       INDRAJITH KK     38      84.44
# 11          JISHNU VS     40      88.89
# 12       JISHNURAJ MP     38      84.44
# 13             JOPIKA     37      82.22
# 14       KEERTHI RAVI     41      91.11
# 15          KIRAN K S     44      97.78
# 16        LUBNA NIZAR     40      88.89
# 17     MANCY MAMACHAN     41      91.11
# 18         MERLIN P M     40      88.89
# 19    MOHAMMED SAFEER     39      86.67
# 20   MUHAMMED SIRAJ K     43      95.56
# 21    NANDAKRISHNAN N      0       0.00
# ...

# %%
#1) Number of movies released in 2020.
netflix=pd.read_csv("C:\\Users\\PC\\Documents\\DA\\datas\\netflix_titles_2021.csv")
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#1) Number of movies released in 2020.
movie_2020=netflix.query('release_year==2020 & type=="Movie"')
movie_2020
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78       s79  Movie                                     Tughlaq Durbar
# 84       s85  Movie                               Omo Ghetto: the Saga
# 103     s104  Movie                                     Shadow Parties
# ...      ...    ...                                                ...
# 3046   s3047  Movie                      All the Freckles in the World
# 3060   s3061  Movie                                      Ghost Stories
# 5972   s5973  Movie                                   #cats_the_mewvie
# 7594   s7595  Movie                 Norm of the North: Family Vacation
# 8099   s8100  Movie                                        Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
pivot=pd.pivot_table(columns='rating',values='release_year',data=netflix,aggfunc=np.median)
pivot.T
# Out:
#           release_year
# rating
# 66 min            2015
# 74 min            2017
# 84 min            2010
# G                 2004
# NC-17             2014
# NR                2015
# PG                2012
# PG-13             2011
# R                 2014
# TV-14             2017
# TV-G              2018
# TV-MA             2018
# TV-PG             2017
# TV-Y              2018
# TV-Y7             2017
# TV-Y7-FV          2015
# UR                2008

# %% [markdown]
# # 2 Display ratings of TV shows each year.

# %%
BM = netflix.type == 'TV Show'

# %%
netflix[BM].release_year.value_counts()
# Out:
# 2020    436
# 2019    397
# 2018    380
# 2021    315
# 2017    265
# 2016    244
# 2015    162
# 2014     88
# 2012     64
# 2013     63
# 2010     40
# 2011     40
# 2009     34
# 2008     23
# 2006     14
# 2007     14
# 2005     13
# 2003     10
# 2004      9
# 1999      7
# 2002      7
# 2001      5
# 1993      4
# 2000      4
# 1997      4
# 1998      4
# 1990      3
# 1996      3
# 1992      3
# 1995      2
# 1994      2
# 1988      2
# 1986      2
# 1989      1
# 1967      1
# 1985      1
# 1946      1
# 1981      1
# 1972      1
# 1979      1
# 1977      1
# 1991      1
# 1974      1
# 1925      1
# 1945      1
# 1963      1
# Name: release_year, dtype: int64

# %%
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)
